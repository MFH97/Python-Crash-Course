# %% [markdown]
# <a href="https://colab.research.google.com/github/MFH97/Python-Crash-Course/blob/main/Chp16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The datasets that were mentioned in the book is no longer available in 2025. So I had to refer to the author's [Github](https://github.com/ehmatthes/pcc_3e/tree/main/chapter_16) for the updated data and codes.

# %% [markdown]
# **Parsing the CSV File Headers**

# %%
from pathlib import Path
import csv


path = Path('sitka_weather_07-2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)
print(header_row)
print()
#Printing the Headers and Their Positions
for index, column_header in enumerate(header_row):
    print(index, column_header)
# Out:
# ['STATION', 'NAME', 'DATE', 'TAVG', 'TMAX', 'TMIN']
#
# 0 STATION
# 1 NAME
# 2 DATE
# 3 TAVG
# 4 TMAX
# 5 TMIN

# %% [markdown]
# **Extracting and Reading Data**

# %%
from pathlib import Path
import csv


path = Path('sitka_weather_07-2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract high temperatures.
highs = []
for row in reader:
    high = int(row[4])
    highs.append(high)

print(highs)
# Out:
# [61, 60, 66, 60, 65, 59, 58, 58, 57, 60, 60, 60, 57, 58, 60, 61, 63, 63, 70, 64, 59, 63, 61, 58, 59, 64, 62, 70, 70, 73, 66]

# %% [markdown]
# **Plotting Data in a Temperature Chart**

# %%
from pathlib import Path
import csv

import matplotlib.pyplot as plt


path = Path('sitka_weather_07-2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract high temperatures.
highs = []
for row in reader:
    high = int(row[4])
    highs.append(high)

# Plot the high temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(highs, color='red')

# Format plot.
ax.set_title("Daily High Temperatures, July 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %% [markdown]
# **The datetime Module**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Plotting Dates**

# %%
#Plotting Dates
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt


path = Path('sitka_weather_07-2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates and high temperatures.
dates, highs = [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    dates.append(current_date)
    highs.append(high)

# Plot the high temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red')

# Format plot.
ax.set_title("Daily High Temperatures, July 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %% [markdown]
# **Plotting a Longer Timeframe**

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt


path = Path('sitka_weather_2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates and high temperatures.
dates, highs = [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    dates.append(current_date)
    highs.append(high)

# Plot the high temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red')

# Format plot.
ax.set_title("Daily High Temperatures, 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %% [markdown]
# **Plotting a Second Data Series**

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt


path = Path('sitka_weather_2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates, and high and low temperatures.
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    low = int(row[5])
    dates.append(current_date)
    highs.append(high)
    lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red')
ax.plot(dates, lows, color='blue')

# Format plot.
ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %% [markdown]
# **Shading an Area in the Chart**

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt

path = Path('sitka_weather_2021_simple.csv')
#path = Path('weather_data/sitka_weather_2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates, and high and low temperatures.
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    low = int(row[5])
    dates.append(current_date)
    highs.append(high)
    lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red', alpha=0.5)
ax.plot(dates, lows, color='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %% [markdown]
# # death_valley_2021

# %%
from pathlib import Path
import csv


path = Path('death_valley_2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)
print(header_row)
print()
#Printing the Headers and Their Positions
for index, column_header in enumerate(header_row):
    print(index, column_header)
# Out:
# ['STATION', 'NAME', 'DATE', 'TMAX', 'TMIN', 'TOBS']
#
# 0 STATION
# 1 NAME
# 2 DATE
# 3 TMAX
# 4 TMIN
# 5 TOBS

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt

path = Path('death_valley_2021_simple.csv')
#path = Path('weather_data/death_valley_2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates, and high and low temperatures.
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    high = int(row[4])
    low = int(row[4])
    dates.append(current_date)
    highs.append(high)
    lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red', alpha=0.5)
ax.plot(dates, lows, color='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
ax.set_title("Daily High and Low Temperatures, 2021", fontsize=24)
ax.set_xlabel('', fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()

# %% [markdown]
# **Error-Checking**

# %%
from pathlib import Path
import csv
from datetime import datetime

import matplotlib.pyplot as plt

path = Path('death_valley_2021_simple.csv')
#path = Path('weather_data/death_valley_2021_simple.csv')
lines = path.read_text().splitlines()

reader = csv.reader(lines)
header_row = next(reader)

# Extract dates, and high and low temperatures.
dates, highs, lows = [], [], []
for row in reader:
    current_date = datetime.strptime(row[2], '%Y-%m-%d')
    try:
        high = int(row[3])
        low = int(row[4])
    except ValueError:
        print(f"Missing data for {current_date}")
    else:
        dates.append(current_date)
        highs.append(high)
        lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn-v0_8')
fig, ax = plt.subplots()
ax.plot(dates, highs, color='red', alpha=0.5)
ax.plot(dates, lows, color='blue', alpha=0.5)
ax.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
title = "Daily High and Low Temperatures, 2021\nDeath Valley, CA"
ax.set_title(title, fontsize=20)
fig.autofmt_xdate()
ax.set_ylabel("Temperature (F)", fontsize=16)
ax.tick_params(labelsize=16)

plt.show()
# Out:
# Missing data for 2021-05-04 00:00:00

# %% [markdown]
# # try It yourself
#
#  **16-1**. San Francisco: Are temperatures in San Francisco more like temperatures
# in Sitka or temperatures in Death Valley? Generate a high-low temperature
# plot for San Francisco and make a comparison . (You can download weather
# data for almost any location from http://www.wunderground.com/history/ .
# Enter a location and date range, scroll to the bottom of the page, and find a
# link labeled Comma-Delimited File . Right-click this link, and save the data as a
# CSV file .)
#
#  **16-2**. Sitka-Death Valley Comparison: The temperature scales on the Sitka
# and Death Valley graphs reflect the different ranges of the data . To accu
# rately compare the temperature range in Sitka to that of Death Valley, you
# need identical scales on the y-axis . Change the settings for the y-axis on
# one or both of the charts in Figures 16-5 and 16-6, and make a direct com
# parison between temperature ranges in Sitka and Death Valley (or any two
# places you want to compare) . You can also try plotting the two data sets on
# the same chart .
#
#  **16-3**. Rainfall: Choose any location you’re interested in, and make a visualiza
# tion that plots its rainfall . Start by focusing on one month’s data, and then once
# your code is working, run it for a full year’s data .
#
# **16-4**. Explore: Generate a few more visualizations that examine any other
# weather aspect you’re interested in for any locations you’re curious about

# %% [markdown]
# # mapping global data sets: json format

# %%
from pathlib import Path
import json


# Read data as a string and convert to a Python object.
path = Path('eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Create a more readable version of the data file.
path = Path('ereadable_eq_data.geojson')
readable_contents = json.dumps(all_eq_data, indent=4)
path.write_text(readable_contents)
# Out:
# 223652

# %%
from pathlib import Path
import json


# Read data as a string and convert to a Python object.
path = Path('eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))
# Out:
# 160

# %%
from pathlib import Path
import json


# Read data as a string and convert to a Python object.
path = Path('eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']

mags = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    mags.append(mag)

print(mags[:10])
# Out:
# [1.6, 1.6, 2.2, 3.7, 2.92000008, 1.4, 4.6, 4.5, 1.9, 1.8]

# %%
from pathlib import Path
import json


# Read data as a string and convert to a Python object.
path = Path('eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']

mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

print(mags[:10])
print(lons[:5])
print(lats[:5])
# Out:
# [1.6, 1.6, 2.2, 3.7, 2.92000008, 1.4, 4.6, 4.5, 1.9, 1.8]
# [-150.7585, -153.4716, -148.7531, -159.6267, -155.248336791992]
# [61.7591, 59.3152, 63.1633, 54.5612, 18.7551670074463]

# %%
from pathlib import Path
import json

import plotly.express as px


# Read data as a string and convert to a Python object.
path = Path('eq_data_1_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']

mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

title = 'Global Earthquakes'
fig = px.scatter_geo(lat=lats, lon=lons, title=title)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3b64aa2a-d87f-403d-9b0b-cc536c1966d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3b64aa2a-d87f-403d-9b0b-cc536c1966d5")) {                    Plotly.newPlot(                        "3b64aa2a-d87f-403d-9b0b-cc536c1966d5",                        [{"geo":"geo","hovertemplate":"lat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[61.7591,59.3152,63.1633,54.5612,18.7551670074463,62.3994,36.3592,-6.686,62.9779,63.671,60.2138,1.7827,62.8383,38.1911,10.6172,34.0223333,65.6749,36.6408348,17.9403333333333,34.0358333,57.0429,34.1478333,65.7868,38.788166,33.4873333,23.1392,40.133,38.8330002,61.3358,34.1458333,56.4973,33.9961667,38.8375015,38.0322,46.6085,60.2597,-22.4542,37.2714996,-22.5126,18.0228,14.0047,18.7840003967285,36.5928,62.7581,38.7890015,19.1723327636719,17.9616666666667,32.3988333,62.9998,35.40652466,19.2148342132568,34.4295,18.7806663513184,37.6073341,38.8364983,18.844165802002,18.8145008087158,-57.4218,18.871000289917,18.053,37.3801651,-15.7921,33.851,59.4819,-41.1132,17.9673333333333,18.8893337249756,59.7672,-22.7765,46.608666666666664,9.3085,-22.9375,33.9833333,33.9591667,39.571,38.831665,38.1459999,60.0022,64.4417,35.42264175,61.0573,49.8554,-4.4681,38.1469,34.4469,60.1086,38.6049995,38.1895,33.4828333,49.4355,61.363,35.6796667,17.9166666666667,35.634,26.8575,34.8471667,19.2016658782959,9.1837,61.2685,34.8325,33.9111667,60.1066,36.008,60.0076,38.1642,19.1723327636719,17.9766666666667,63.1835,17.9313333333333,0.7303,38.229,63.2786,18.0216666666667,19.15016746521,33.8415,33.2116667,64.2826,35.62977219,17.9536666666667,19.2198333740234,37.2803333,9.2613,62.834,17.9876666666667,35.63026047,19.1965007781982,9.2256,34.9351667,38.1247,18.8588333129883,19.2098331451416,59.645,61.8753,-22.0803,35.0381667,62.7912,62.2087,61.951,35.39769745,26.526,36.1055,26.8007,35.2976667,61.4567,17.9888,36.1043333,35.65401077,34.018,38.2105,61.815,59.41,62.7391,46.428,37.799,46.871,33.4948333,17.9311666666667,54.6414,38.0496667,33.5846667],"legendgroup":"","lon":[-150.7585,-153.4716,-148.7531,-159.6267,-155.248336791992,-149.173,22.0768,129.5079,-150.5896,-145.9089,-141.4547,127.3132,-148.8272,-117.7935,140.7506,-117.153,-145.4421,-121.2634964,-66.9111666666667,-117.2585,-155.6147,-116.7213333,-149.8307,-122.7611694,-116.5603333,120.5613,-119.6498,-122.8125,-148.1118,-116.7225,-149.5698,-117.6645,-122.8128357,-117.8823,-119.85066666666667,-152.1079,169.9229,-121.6484985,170.0243,-66.7635,-92.4289,-155.164993286133,70.9912,-148.6377,-122.7259979,-155.468338012695,-66.9825,-115.2618333,-151.0452,-97.87510681,-155.471664428711,-106.8323,-155.249328613281,-121.6518326,-122.809166,-155.20133972168,-155.196838378906,-25.2674,-155.201507568359,-66.0613333333333,-118.6138306,-173.0821,-118.3441667,-153.1899,-90.2955,-66.8163333333333,-155.223831176758,-153.0568,170.0847,-119.851,126.6017,170.0666,-117.8606667,-118.0525,-119.0627,-122.8151703,-122.4605026,-152.0841,-148.0019,-97.87393951,-152.4105,155.733,-76.9306,-117.9906,-106.8794,-151.1797,-121.9348297,-117.797,-116.5668333,144.3998,-151.7855,-117.54,-66.8848333333333,-117.5738333,126.5138,-118.9135,-155.495498657227,126.6103,-146.8972,-118.9733333,-117.78,-147.7583,69.8183,-152.79,-117.983,-155.473327636719,-67.0445,-150.2319,-67.0065,99.8701,-117.8619,-150.5417,-66.7698333333333,-155.369003295898,-116.751,-116.7571667,-149.8615,-97.95739746,-66.8751666666667,-155.382827758789,-118.3951667,126.6898,-148.391,-66.9738333333333,-97.97806549,-155.385162353516,126.6692,-116.7038333,-117.9977,-155.22216796875,-155.406326293945,-152.2639,-149.4109,-68.5779,-116.9765,-148.4051,-149.517,-149.1666,-97.88280487,126.4621,-117.8855,126.4309,-118.5718333,-150.8127,-67.00 ...

# %%
from pathlib import Path
import json

import plotly.express as px


# Read data as a string and convert to a Python object.
path = Path('eq_data_30_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']

mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

title = 'Global Earthquakes'
fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="301ecd80-22af-4057-a6b7-f2c35d836b9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("301ecd80-22af-4057-a6b7-f2c35d836b9f")) {                    Plotly.newPlot(                        "301ecd80-22af-4057-a6b7-f2c35d836b9f",                        [{"geo":"geo","hovertemplate":"size=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[61.7591,59.3152,63.1633,54.5612,18.7551670074463,62.3994,36.3592,-6.686,62.9779,63.671,60.2138,1.7827,62.8383,38.1911,10.6172,34.0223333,65.6749,36.6408348,17.9403333333333,34.0358333,57.0429,34.1478333,65.7868,38.788166,33.4873333,23.1392,40.133,38.8330002,61.3358,34.1458333,56.4973,33.9961667,38.8375015,38.0322,46.6085,60.2597,-22.4542,37.2714996,-22.5126,18.0228,14.0047,18.7840003967285,36.5928,62.7581,38.7890015,19.1723327636719,17.9616666666667,32.3988333,62.9998,35.40652466,19.2148342132568,34.4295,18.7806663513184,37.6073341,38.8364983,18.844165802002,18.8145008087158,-57.4218,18.871000289917,18.053,37.3801651,-15.7921,33.851,59.4819,-41.1132,17.9673333333333,18.8893337249756,59.7672,-22.7765,46.608666666666664,9.3085,-22.9375,33.9833333,33.9591667,39.571,38.831665,38.1459999,60.0022,64.4417,35.42264175,61.0573,49.8554,-4.4681,38.1469,34.4469,60.1086,38.6049995,38.1895,33.4828333,49.4355,61.363,35.6796667,17.9166666666667,35.634,26.8575,34.8471667,19.2016658782959,9.1837,61.2685,34.8325,33.9111667,60.1066,36.008,60.0076,38.1642,19.1723327636719,17.9766666666667,63.1835,17.9313333333333,0.7303,38.229,63.2786,18.0216666666667,19.15016746521,33.8415,33.2116667,64.2826,35.62977219,17.9536666666667,19.2198333740234,37.2803333,9.2613,62.834,17.9876666666667,35.63026047,19.1965007781982,9.2256,34.9351667,38.1247,18.8588333129883,19.2098331451416,59.645,61.8753,-22.0803,35.0381667,62.7912,62.2087,61.951,35.39769745,26.526,36.1055,26.8007,35.2976667,61.4567,17.9888,36.1043333,35.65401077,34.018,38.2105,61.815,59.41,62.7391,46.428,37.799,46.871,33.4948333,17.9311666666667,54.6414,38.0496667,33.5846667,38.8148346,33.8668333,33.8655,61.1399,17.9558333333333,38.833168,-8.7896,63.2444,-31.458,35.944,64.874,35.3835,59.8884,-33.7721,17.9188333333333,17.9575,19.2275,19.5101666666667,17.9561666666667,17.9661666666667,17.9681666666667,44.5072,54.5694,18.5973333333333,33.2315,38.8226662,61.4341,19.4336666666667,52.3524,61.49,38.5189,19.4688339233398,19.4673333333333,5.4101,38.1329,17.993,34.6978333,36.7981667,58.863,41.3854,38.8343315,38.1605,64.9966,38.1094,17.877,38.1209,63.5733,61.8826,-22.6404,37.9954,60.2457,36.6616,62.8409,65.3864,38.8221664,38.7741667,-17.0794,38.8203333,32.5151,17.9598333333333,37.3361667,58.7063,19.2283325195312,61.8997,46.9351667,33.9943352,36.8136667,38.0256,17.9801666666667,17.949,51.0909,51.61,32.41607666,46.24766666666667,46.230666666666664,38.1901,57.4951,17.928,37.9001667,19.2283325195312,-22.6831,35.6683333,33.0373333,18.0345,36.6269,33.9685,35.6906667,35.60830688,-30.6642,36.5588333,36.6735,38.8336667,34.9883333,19.2438335418701,18.8523330688477,36.8528333,17.972,38.1892,52.2173,22.8845,54.4659,31.70688049,34.0270004,37.4096667,37.408,62.1507,37.4093333,33.1706667,37.4093333,37.4086667,61.7085,17.9888333333333,63.3437,61.3112,60.4585,31.66828959,37.4085,36.4523333,44.4816,33.8543333,33.1695,38.6255,17.9948333333333,63.1226,64.0009,64.6054,67.787,31.02,55.601,31.7177,36.654,-22.6471,62.543,63.2674,40.2806667,57.6521,41.0453333,60.3791,57.9375,38.8190002,60.3646,34.0615,38.6258333,18.0268333333333,19.2076663970947,17.9945,38.6285,19.2061672210693,19.246166229248,38.6265,2.6328,35.639,18.1128333333333,61.5575,38.1716,19.3110008239746,64.6118,38.1791,19.2403335571289,19.2058334350586,61.2817,38.8128333,17.9386666 ...

# %%
from pathlib import Path
import json

import plotly.express as px


# Read data as a string and convert to a Python object.
path = Path('eq_data_30_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']

mags, lons, lats = [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

title = 'Global Earthquakes'
fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
        color=mags,
        color_continuous_scale='Viridis',
        labels={'color':'Magnitude'},
        projection='natural earth',
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="02502247-af12-4225-84b1-7eef2b3d2f5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("02502247-af12-4225-84b1-7eef2b3d2f5e")) {                    Plotly.newPlot(                        "02502247-af12-4225-84b1-7eef2b3d2f5e",                        [{"geo":"geo","hovertemplate":"size=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cbr\u003eMagnitude=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[61.7591,59.3152,63.1633,54.5612,18.7551670074463,62.3994,36.3592,-6.686,62.9779,63.671,60.2138,1.7827,62.8383,38.1911,10.6172,34.0223333,65.6749,36.6408348,17.9403333333333,34.0358333,57.0429,34.1478333,65.7868,38.788166,33.4873333,23.1392,40.133,38.8330002,61.3358,34.1458333,56.4973,33.9961667,38.8375015,38.0322,46.6085,60.2597,-22.4542,37.2714996,-22.5126,18.0228,14.0047,18.7840003967285,36.5928,62.7581,38.7890015,19.1723327636719,17.9616666666667,32.3988333,62.9998,35.40652466,19.2148342132568,34.4295,18.7806663513184,37.6073341,38.8364983,18.844165802002,18.8145008087158,-57.4218,18.871000289917,18.053,37.3801651,-15.7921,33.851,59.4819,-41.1132,17.9673333333333,18.8893337249756,59.7672,-22.7765,46.608666666666664,9.3085,-22.9375,33.9833333,33.9591667,39.571,38.831665,38.1459999,60.0022,64.4417,35.42264175,61.0573,49.8554,-4.4681,38.1469,34.4469,60.1086,38.6049995,38.1895,33.4828333,49.4355,61.363,35.6796667,17.9166666666667,35.634,26.8575,34.8471667,19.2016658782959,9.1837,61.2685,34.8325,33.9111667,60.1066,36.008,60.0076,38.1642,19.1723327636719,17.9766666666667,63.1835,17.9313333333333,0.7303,38.229,63.2786,18.0216666666667,19.15016746521,33.8415,33.2116667,64.2826,35.62977219,17.9536666666667,19.2198333740234,37.2803333,9.2613,62.834,17.9876666666667,35.63026047,19.1965007781982,9.2256,34.9351667,38.1247,18.8588333129883,19.2098331451416,59.645,61.8753,-22.0803,35.0381667,62.7912,62.2087,61.951,35.39769745,26.526,36.1055,26.8007,35.2976667,61.4567,17.9888,36.1043333,35.65401077,34.018,38.2105,61.815,59.41,62.7391,46.428,37.799,46.871,33.4948333,17.9311666666667,54.6414,38.0496667,33.5846667,38.8148346,33.8668333,33.8655,61.1399,17.9558333333333,38.833168,-8.7896,63.2444,-31.458,35.944,64.874,35.3835,59.8884,-33.7721,17.9188333333333,17.9575,19.2275,19.5101666666667,17.9561666666667,17.9661666666667,17.9681666666667,44.5072,54.5694,18.5973333333333,33.2315,38.8226662,61.4341,19.4336666666667,52.3524,61.49,38.5189,19.4688339233398,19.4673333333333,5.4101,38.1329,17.993,34.6978333,36.7981667,58.863,41.3854,38.8343315,38.1605,64.9966,38.1094,17.877,38.1209,63.5733,61.8826,-22.6404,37.9954,60.2457,36.6616,62.8409,65.3864,38.8221664,38.7741667,-17.0794,38.8203333,32.5151,17.9598333333333,37.3361667,58.7063,19.2283325195312,61.8997,46.9351667,33.9943352,36.8136667,38.0256,17.9801666666667,17.949,51.0909,51.61,32.41607666,46.24766666666667,46.230666666666664,38.1901,57.4951,17.928,37.9001667,19.2283325195312,-22.6831,35.6683333,33.0373333,18.0345,36.6269,33.9685,35.6906667,35.60830688,-30.6642,36.5588333,36.6735,38.8336667,34.9883333,19.2438335418701,18.8523330688477,36.8528333,17.972,38.1892,52.2173,22.8845,54.4659,31.70688049,34.0270004,37.4096667,37.408,62.1507,37.4093333,33.1706667,37.4093333,37.4086667,61.7085,17.9888333333333,63.3437,61.3112,60.4585,31.66828959,37.4085,36.4523333,44.4816,33.8543333,33.1695,38.6255,17.9948333333333,63.1226,64.0009,64.6054,67.787,31.02,55.601,31.7177,36.654,-22.6471,62.543,63.2674,40.2806667,57.6521,41.0453333,60.3791,57.9375,38.8190002,60.3646,34.0615,38.6258333,18.0268333333333,19.2076663970947,17.9945,38.6285,19.2061672210693,19.246166229248,38.6265,2.6328,35.639,18.1128333333333,61.5575,38.1716,19.3110008239746,64.6118,38.1791,19.2403335571289,19.2058 ...

# %%
from pathlib import Path
import json

import plotly.express as px


# Read data as a string and convert to a Python object.
path = Path('eq_data_30_day_m1.geojson')
contents = path.read_text(encoding='utf-8')
all_eq_data = json.loads(contents)

# Examine all earthquakes in the dataset.
all_eq_dicts = all_eq_data['features']

mags, lons, lats, eq_titles = [], [], [], []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    eq_title = eq_dict['properties']['title']
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)
    eq_titles.append(eq_title)

title = 'Global Earthquakes'
fig = px.scatter_geo(lat=lats, lon=lons, size=mags, title=title,
        color=mags,
        color_continuous_scale='Viridis',
        labels={'color':'Magnitude'},
        projection='natural earth',
        hover_name=eq_titles,
    )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8fa80db0-b777-4db3-9475-8d36474b3b3d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fa80db0-b777-4db3-9475-8d36474b3b3d")) {                    Plotly.newPlot(                        "8fa80db0-b777-4db3-9475-8d36474b3b3d",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003esize=%{marker.size}\u003cbr\u003elat=%{lat}\u003cbr\u003elon=%{lon}\u003cbr\u003eMagnitude=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["M 1.6 - 27 km NNW of Susitna, Alaska","M 1.6 - 63 km SE of Pedro Bay, Alaska","M 2.2 - 27 km SSE of Cantwell, Alaska","M 3.7 - south of Alaska","M 2.9 - 49 km SE of Naalehu, Hawaii","M 1.4 - 44 km NE of Susitna North, Alaska","M 4.6 - 49 km SSE of Koróni, Greece","M 4.5 - Banda Sea","M 1.9 - 54 km N of Petersville, Alaska","M 1.8 - 34 km SSW of Fort Greely, Alaska","M 1.7 - 121 km NW of Yakutat, Alaska","M 4.1 - 77 km W of Tobelo, Indonesia","M 1.6 - 61 km S of Cantwell, Alaska","M 1.2 - 35 km SE of Mina, Nevada","M 5.1 - 97 km NNE of Fais, Micronesia","M 1.0 - 5km SE of Redlands, CA","M 1.8 - 31 km WNW of Central, Alaska","M 2.8 - 16km NW of Pinnacles, CA","M 2.3 - 3 km S of Guánica, Puerto Rico","M 1.0 - 1km S of Loma Linda, CA","M 2.5 - 88 km W of Akhiok, Alaska","M 1.8 - 17km SE of Big Bear City, CA","M 1.4 - 35 km NNE of Rampart, Alaska","M 1.1 - 1km NNW of The Geysers, CA","M 1.1 - 13km SE of Anza, CA","M 4.4 - 10 km E of Yujing, Taiwan","M 1.3 - Nevada","M 1.2 - 8km W of Cobb, CA","M 1.4 - 44 km ESE of Knik River, Alaska","M 1.5 - 17km NW of Morongo Valley, CA","M 2.8 - 206 km SE of Chiniak, Alaska","M 1.1 - 3km SE of Chino, CA","M 1.2 - 8km WNW of Cobb, CA","M 1.8 - 37 km NW of Silver Peak, Nevada","M 1.7 - 9 km SSE of Desert Aire, Washington","M 1.9 - 33 km NW of Ninilchik, Alaska","M 4.6 - 233 km ESE of Tadine, New Caledonia","M 1.4 - 16km N of Morgan Hill, CA","M 4.6 - 245 km ESE of Tadine, New Caledonia","M 3.1 - 0 km NE of Magas Arriba, Puerto Rico","M 4.5 - 61 km SSW of Ocós, Guatemala","M 2.2 - 53 km SE of Naalehu, Hawaii","M 4.3 - 33 km SSE of Jurm, Afghanistan","M 2.5 - 72 km SSE of Cantwell, Alaska","M 1.2 - 3km ENE of The Geysers, CA","M 2.2 - 3 km SSE of Pāhala, Hawaii","M 2.0 - 6 km ESE of La Parguera, Puerto Rico","M 1.9 - 8km NW of Delta, B.C., MX","M 1.8 - 57 km NNW of Petersville, Alaska","M 2.3 - 6 km ENE of Union City, Oklahoma","M 2.1 - 1 km NNE of Pāhala, Hawaii","M 3.0 - 4 km SSW of Abeytas, New Mexico","M 2.8 - 47 km SE of Naalehu, Hawaii","M 1.1 - 13km SE of Livermore, CA","M 1.0 - 8km WNW of Cobb, CA","M 2.1 - 46 km ESE of Naalehu, Hawaii","M 2.1 - 49 km SE of Naalehu, Hawaii","M 5.2 - South Sandwich Islands region","M 2.5 - 45 km ESE of Naalehu, Hawaii","M 3.0 - 2 km N of Yaurel, Puerto Rico","M 1.3 - 4km SSW of Round Valley, CA","M 4.8 - 78 km ENE of Hihifo, Tonga","M 1.7 - 2km N of Torrance, CA","M 2.5 - 61 km ESE of Pedro Bay, Alaska","M 5.0 - southeast of Easter Island","M 2.2 - 2 km S of Indios, Puerto Rico","M 2.8 - 42 km ESE of Naalehu, Hawaii","M 1.6 - 58 km E of Pedro Bay, Alaska","M 4.8 - 264 km ESE of Tadine, New Caledonia","M 2.2 - 9 km SSE of Desert Aire, Washington","M 4.8 - 45 km E of Cortes, Philippines","M 4.8 - 265 km E of Vao, New Caledonia","M 1.1 - 4km S of Walnut, CA","M 1.2 - 1km W of South Whittier, CA","M 1.4 - 16 km ESE of Fernley, Nevada","M 1.2 - 8km NW of The Geysers, CA","M 1.4 - 6km NE of Black Point-Green Point, CA","M 1.6 - 20 km WNW of Happy Valley, Alaska","M 1.1 - 42 km SSW of South Van Horn, Alaska","M 2.2 - 7 km ENE of Union City, Oklahoma","M 1.0 - 68 km W of Tyonek, Alaska","M 4.4 - 95 km SSW of Severo-Kuril’sk, Russia","M 4.5 - 49 km NW of B ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

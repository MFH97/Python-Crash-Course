# %% [markdown]
# <a href="https://colab.research.google.com/github/MFH97/Python-Crash-Course/blob/main/Chp3ans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Answers for chp3 ~Try it yourself

# %% [markdown]
# 3-1. Names: Store the names of a few of your friends in a list called names. Print each person’s name by accessing each element in the list, one at a time.

# %%
#3-1
names = ['eirfan', 'vishnu', 'haziq','farhan']
print(names)
print(names[0].title())
print(names[1].title())
print(names[2].title())
print(names[3].title())
# Out:
# ['eirfan', 'vishnu', 'haziq', 'farhan']
# Eirfan
# Vishnu
# Haziq
# Farhan

# %% [markdown]
# 3-2. Greetings: Start with the list you used in Exercise 3-1, but instead of just printing each person’s name, print a message to them. The text of each message should be the same, but each message should be personalized with the person’s name.

# %%
#3-2
names = ['eirfan', 'vishnu', 'haziq','farhan']
print("Whats up " + names[0].title() + '!')
print("Whats up " + names[1].title() + '!')
print("Whats up " + names[2].title() + '!')
print("Whats up " + names[3].title() + '!')
# Out:
# Whats up Eirfan!
# Whats up Vishnu!
# Whats up Haziq!
# Whats up Farhan!

# %% [markdown]
# 3-3. Your Own List: Think of your favorite mode of transportation, such as a motorcycle or a car, and make a list that stores several examples. Use your list to print a series of statements about these items, such as “I would like to own a Honda motorcycle.

# %%
#3-3
motorcycles = ['ducati','yamaha','suzuki','honda']
message = "I would like to own a " + motorcycles[0] + "!"
print(message)
# Out:
# I would like to own a ducati!

# %% [markdown]
# 3-4. Guest List: If you could invite anyone, living or deceased, to dinner, who would you invite? Make a list that includes at least three people you’d like to invite to dinner. Then use your list to print a message to each person, inviting them to dinner.
#
# 3-5. Changing Guest List: You just heard that one of your guests can’t make the dinner, so you need to send out a new set of invitations . You’ll have to think of someone else to invite.
#
# Start with your program from Exercise 3-4 . Add a print statement at the end of your program stating the name of the guest who can’t make it.
#
# Modify your list, replacing the name of the guest who can’t make it with the name of the new person you are inviting.
#
# Print a second set of invitation messages, one for each person who is still in your list.

# %%
#3-4&5
Guest = ['eirfan', 'vishnu', 'haziq','farhan']
print(Guest[0].title() + " welcome to my dinner treat!")
print(Guest[1].title() + " welcome to my dinner treat!")
print(Guest[2].title() + " welcome to my dinner treat!")
print(Guest[3].title() + " welcome to my dinner treat!")

Notcoming = Guest.pop(2)
print(Notcoming.title() + " cant make it for dinner :(")
print(Guest)
Guest.insert(2,'calvin')
print(Guest)
print()
print(Guest[0].title() + " welcome to my dinner treat!")
print(Guest[1].title() + " welcome to my dinner treat!")
print(Guest[2].title() + " welcome to my dinner treat!")
print(Guest[3].title() + " welcome to my dinner treat!")
# Out:
# Eirfan welcome to my dinner treat!
# Vishnu welcome to my dinner treat!
# Haziq welcome to my dinner treat!
# Farhan welcome to my dinner treat!
# Haziq cant make it for dinner :(
# ['eirfan', 'vishnu', 'farhan']
# ['eirfan', 'vishnu', 'calvin', 'farhan']
#
# Eirfan welcome to my dinner treat!
# Vishnu welcome to my dinner treat!
# Calvin welcome to my dinner treat!
# Farhan welcome to my dinner treat!

# %% [markdown]
# 3-6. More Guests: You just found a bigger dinner table, so now more space is available. Think of three more guests to invite to dinner.
#
# Start with your program from Exercise 3-4 or Exercise 3-5. Add a print statement to the end of your program informing people that you found a bigger dinner table.
#
# Use insert() to add one new guest to the beginning of your list.
#
# Use insert() to add one new guest to the middle of your list.
#
# Use append() to add one new guest to the end of your list.
#
# Print a new set of invitation messages, one for each person in your list.

# %%
#3-6
Guest = ['eirfan', 'vishnu', 'haziq','farhan']
Notcoming = 'haziq'
Guest.remove(Notcoming)
print(Notcoming.title() + " cant make it for dinner :(")
print(Guest)
Guest.insert(2,'calvin')
Guest.insert(0,'sarah')
Guest.append('keziah')
print()


print("Updated Guest list: " + str(Guest))#prints updated guest list
print()
print(Guest[0].title() + " welcome to my dinner treat!")
print(Guest[1].title() + " welcome to my dinner treat!")
print(Guest[2].title() + " welcome to my dinner treat!")
print(Guest[3].title() + " welcome to my dinner treat!")
print(Guest[4].title() + " welcome to my dinner treat!")
print(Guest[5].title() + " welcome to my dinner treat!")
print("### I found a bigger diner table! ###")
# Out:
# Haziq cant make it for dinner :(
# ['eirfan', 'vishnu', 'farhan']
#
# Updated Guest list: ['sarah', 'eirfan', 'vishnu', 'calvin', 'farhan', 'keziah']
#
# Sarah welcome to my dinner treat!
# Eirfan welcome to my dinner treat!
# Vishnu welcome to my dinner treat!
# Calvin welcome to my dinner treat!
# Farhan welcome to my dinner treat!
# Keziah welcome to my dinner treat!
# ### I found a bigger diner table! ###

# %% [markdown]
# 3-7. Shrinking Guest List: You just found out that your new dinner table won’t arrive in time for the dinner, and you have space for only two guests.
#
# Start with your program from Exercise 3-6. Add a new line that prints a message saying that you can invite only two people for dinner.
#
# Use pop() to remove guests from your list one at a time until only two names remain in your list. Each time you pop a name from your list, print a message to that person letting them know you’re sorry you can’t invite them to dinner.
#
# Print a message to each of the two people still on your list, letting them know they’re still invited.
#
# Use del to remove the last two names from your list, so you have an empty list. Print your list to make sure you actually have an empty list at the end of your program.

# %%
#3-7
Guest = ['sarah','eirfan', 'vishnu', 'calvin','farhan','keziah']
print('Sorry guys, only 2 people are invited for dinner.')
p1 = Guest.pop()
print(p1 + ' see ya next time!')
p2 = Guest.pop()
print(p2+ ' see ya next time!')
p3 = Guest.pop()
print(p3+ ' see ya next time!')
p4 = Guest.pop(0)
print(p4+ ' see ya next time!')

print()
print(Guest[0] + ' see ya at dinner!')
print(Guest[1] + ' see ya at dinner!')
del Guest[0]
del Guest[0]

print(Guest) #Prints empty list
#if you want to use an
#item as you remove it, use the pop() method
# Out:
# Sorry guys, only 2 people are invited for dinner.
# keziah see ya next time!
# farhan see ya next time!
# calvin see ya next time!
# sarah see ya next time!
#
# eirfan see ya at dinner!
# vishnu see ya at dinner!
# []

# %% [markdown]
# 3-8. Seeing the World: Think of at least five places in the world you’d like to visit.
#
# Store the locations in a list.
#
# Make sure the list is not in alphabetical order.
#
# Print your list in its original order.
#
# Don’t worry about printing the list neatly, just print it as a raw Python list.
#
# Use sorted() to print your list in alphabetical order without modifying the actual list.
#
# Show that your list is still in its original order by printing it.
#
# Use sorted() to print your list in reverse alphabetical order without changing the order of the original list.
#
# Show that your list is still in its original order by printing it again.
#
# Use reverse() to change the order of your list. Print the list to show that its order has changed.
#
# Use reverse() to change the order of your list again. Print the list to show it’s back to its original order.
#
# Use sort() to change your list so it’s stored in alphabetical order. Print the list to show that its order has been changed.
#
# Use sort() to change your list so it’s stored in reverse alphabetical order. Print the list to show that its order has changed.

# %%
#3-8
To_visit = ['petra','giza','colosseum','taj mahal','great wall']
print('sorted list:')
print(sorted(To_visit))#Temp sort
print()
print('Original list:')
print(To_visit)#Original list

TempSort = sorted(To_visit)
TempSort.reverse()
print()
print('sorted list:')
print(TempSort)
print()
print('Original list:')
print(To_visit)#Original list
print()

To_visit.reverse()
print(To_visit)
To_visit.reverse()
print(To_visit)
To_visit.sort()
print(To_visit)
To_visit.sort(reverse=True)
print(To_visit)
# Out:
# sorted list:
# ['colosseum', 'giza', 'great wall', 'petra', 'taj mahal']
#
# Original list:
# ['petra', 'giza', 'colosseum', 'taj mahal', 'great wall']
#
# sorted list:
# ['taj mahal', 'petra', 'great wall', 'giza', 'colosseum']
#
# Original list:
# ['petra', 'giza', 'colosseum', 'taj mahal', 'great wall']
#
# ['great wall', 'taj mahal', 'colosseum', 'giza', 'petra']
# ['petra', 'giza', 'colosseum', 'taj mahal', 'great wall']
# ['colosseum', 'giza', 'great wall', 'petra', 'taj mahal']
# ['taj mahal', 'petra', 'great wall', 'giza', 'colosseum']

# %% [markdown]
# 3-9. Dinner Guests: Working with one of the programs from Exercises 3-4 through 3-7 (page 46), use len() to print a message indicating the number of people you are inviting to dinner .

# %%
#3-9
Guest = ['sarah','eirfan', 'vishnu', 'calvin','farhan','keziah']
print('The number of people i have invited are:')
print(len(Guest))
# Out:
# The number of people i have invited are:
# 6

# %% [markdown]
# 3-10. Every Function: Think of something you could store in a list . For example, you could make a list of mountains, rivers, countries, cities, languages, or anything else you’d like. Write a program that creates a list containing these items and then uses each function introduced in this chapter at least once.

# %%
#3-10
"""
Accessing Elements in a List
Using Individual Values from a List
Change add and removing elements
Removig an item by value
Sorting a List Permanently
Sorting a List Temporarily
Printing a List in Reverse Order
Finding the Length of a List
"""


countries = ['india', 'indonesia','Malaysia', 'egypt', 'china','Brazil', 'colombia', 'ethiopia', 'france', 'germany', 'ghana', 'hungary', 'iceland', 'israel', 'italy', 'japan', 'north korea', 'south korea', 'laos', 'lebanon', 'madagascar', 'maldives', 'mexico', 'myanmar', 'nepal', 'nepal', 'new zealand', 'norway', 'pakistan', 'portugal', 'philippines', 'peru', 'qatar', 'russia', 'saudi arabia', 'singapore', 'spain', 'sri lanka', 'syria', 'taiwan', 'turkey', 'thailand', 'tajikistan', 'united states', 'ukraine', 'uzbekistan', 'uganda', 'united kingdom' 'venezuela', 'vietnam', 'yemen', 'zambia', 'zimbabwe']
print(countries)
print()
num = len(countries)
print("Total number of countires: " + str(num))
#Accessing Elements in a List
#Using Individual Values from a List

print(countries[0].title() + " is my motherland!")
print(countries[-1] + ' is the last country in the list.')
print()
#Delete an item
del countries[13]
print(countries)

#Removig item by pop() method
newCountries = countries.pop()
print()
print(newCountries.title() + ' is no longer the last country in the list.')
print()

#Removig an item by value
countries.remove('singapore')
print("After removing 3 countries, we have = " + str(len(countries)))
#Append an item
countries.append('singapore')
#Inserting Elements into a List
countries.insert(0,'zimbabwe')
countries[0] = 'palestine'
print("After adding 2 countries, we have = " + str(len(countries)))
print()
print(countries)
print()
#Sorting a List Temporarily
print("This is temporarily sorted list:")
print(sorted(countries))
#Printing a List in original Order
print()
print("This is original list:")
print(countries)
print()
#Sorting a List Permanently
print("This is Permanently sorted list:")
countries.sort()
print(countries)
#Printing a List in Reverse Order
print()
countries.sort(reverse = True)
print("This is reverse sorted list:")
print(countries)
# Out:
# ['india', 'indonesia', 'Malaysia', 'egypt', 'china', 'Brazil', 'colombia', 'ethiopia', 'france', 'germany', 'ghana', 'hungary', 'iceland', 'israel', 'italy', 'japan', 'north korea', 'south korea', 'laos', 'lebanon', 'madagascar', 'maldives', 'mexico', 'myanmar', 'nepal', 'nepal', 'new zealand', 'norway', 'pakistan', 'portugal', 'philippines', 'peru', 'qatar', 'russia', 'saudi arabia', 'singapore', 'spain', 'sri lanka', 'syria', 'taiwan', 'turkey', 'thailand', 'tajikistan', 'united states', 'ukraine', 'uzbekistan', 'uganda', 'united kingdomvenezuela', 'vietnam', 'yemen', 'zambia', 'zimbabwe']
#
# Total number of countires: 52
# India is my motherland!
# zimbabwe is the last country in the list.
#
# ...
